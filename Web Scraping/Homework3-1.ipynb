# %% [markdown]
# # Scraping Hotel Ratings on Booking #

# %% [markdown]
# In this homework we will practice web scraping on the following [site](https://www.booking.com/searchresults.html?aid=304142&label=gen173nr-1DCAEoggJCAlhYSDNiBW5vcmVmcgV1c19tYYgBAZgBMcIBA2FibsgBDdgBA-gBAfgBApICAXmoAgQ&sid=28d97f630803f9d48b4a1f535cbdd33f&class_interval=1&dest_id=20061717&dest_type=city&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A%2CA&sb_price_type=total&src=index&src_elem=sb&ss=Boston&ssb=empty&ssne_untouched=Cancún&rows=15). Let's get some basic information for each hotel in Boston.
# On each hotel page, scrape the following information:
# 1. Hotel Name
# 2. Class of Rating (Wonderful/Excellent/Very Good/Good)
# 3. Rating Score
# 4. Number of Reviews
#
#
# ** Save the data in "traveler_ratings.csv" in the following format: hotel_name, class_of_rating, rating, num_reviews **
#
# **(10 pts)**
#
# You can see an overview of the information as displayed:
#
#
#
#
#
# ![Information to be scraped](booking_sample.png)

# %%
from bs4 import BeautifulSoup
import sys
import time
import os
import requests
import json
import pandas as pd
from urllib.request import urlopen as uReq
import re

# %%
'''
This code block is just experimenting with the scraped data.
'''
page_url = "https://www.booking.com/searchresults.html?aid=304142&label=gen173nr-1DCAEoggJCAlhYSDNiBW5vcmVmcgV1c19tYYgBAZgBMcIBA2FibsgBDdgBA-gBAfgBApICAXmoAgQ&sid=28d97f630803f9d48b4a1f535cbdd33f&class_interval=1&dest_id=20061717&dest_type=city&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A%2CA&sb_price_type=total&src=index&src_elem=sb&ss=Boston&ssb=empty&ssne_untouched=Canc%C3%BAn&rows=15"
response = requests.get(page_url)
html = response.text.encode('utf-8')
page_soup = BeautifulSoup(html, "lxml")

containers = page_soup.findAll('a', {'class':'hotel_name_link url'})
title = containers[0].findAll('span', {'class' : 'sr-hotel__name'})

paging = page_soup.find('a', {'class':re.compile('paging-next')}) #Find a tag which contains keyword paging-next

urls = page_soup.findAll('a', {'class':'hotel_name_link url'})  
urls[0]['href']

# containers = page_soup.findAll('div', {'data-hotelid': True })
# score = containers[0].findAll('span', {'class' : 'review-score-badge'})
# containers[0]
# hotel_name = containers[0].find('span', {'class':'sr-hotel__name'})
# rating = containers[0].findAll('span', {'class':'review-score-badge'})
# containers[0]
# Out:
# '\n/hotel/us/oakwood-boston.html\n#hotelTmpl'

# %%
'''
Given a webpage, extract hotel names and their corresponding urls; Recursively do 
this task on the next page if it exists. Otherwise exit.

'''
def get_hotel_name_and_url(source_page, hotel_names, hotel_urls):
    response = requests.get(source_page)
    html = response.text.encode('utf-8')
    page_soup = BeautifulSoup(html, "lxml") #raw html data
    
    urls = page_soup.findAll('a', {'class':'hotel_name_link url'})  
    names = page_soup.findAll('span', {'class' : 'sr-hotel__name'})
    
    for url in urls:
        hotel_urls.append('http://booking.com' + url['href'].replace("\n", "")) 
        
    for name in names:
        hotel_names.append(name.text.strip())
        
    #Deterimine if recurse
    paging = page_soup.find('a', {'class':re.compile('paging-next')})
    if paging is None: return  #This is the last page, so exit
    
    source_page = paging['href'] 
    time.sleep(0.5)
    get_hotel_name_and_url(source_page, hotel_names, hotel_urls)  #Recurse on the next page

#     print(paging['href'])
#     if paging is None: return 
#     source_page = 'http://booking.com' + paging['href']
#     get_hotel_name_and_url()

hotel_names = []
hotel_urls = []
source_page = "https://www.booking.com/searchresults.html?aid=304142&label=gen173nr-1DCAEoggJCAlhYSDNiBW5vcmVmcgV1c19tYYgBAZgBMcIBA2FibsgBDdgBA-gBAfgBApICAXmoAgQ&sid=28d97f630803f9d48b4a1f535cbdd33f&class_interval=1&dest_id=20061717&dest_type=city&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A%2CA&sb_price_type=total&src=index&src_elem=sb&ss=Boston&ssb=empty&ssne_untouched=Canc%C3%BAn&rows=15"

get_hotel_name_and_url(source_page, hotel_names, hotel_urls) #After this function call, two lists should be initialized

# %%
hotel_urls[0]
# Out:
# 'http://booking.com/hotel/us/oakwood-boston.html#hotelTmpl'

# %%
rating_class = []
rating_score = []
review_number = []

'''
Retrieve info for individual hotel, using the hotel urls acquired previously
Cost 10min+
'''
def get_hotel_info(hotel_urls):
    
    for url in hotel_urls:
        response = requests.get(url)
        html = response.text.encode('utf-8')
        page_soup = BeautifulSoup(html, "lxml") 
        
        rclass = page_soup.find('span', {'class': 'review-score-widget__text'})
        rscore = page_soup.find('span', {'class': 'review-score-badge'})
        rnumber = page_soup.find('span', {'class': 'review-score-widget__subtext'})
        
        if(rclass is None): rating_class.append(None)
        else: rating_class.append(rclass.text.strip())
         
        if(rscore is None): rating_score.append(None)
        else: rating_score.append(rscore.text.strip())
        
        if(rnumber is None): review_number.append(None)
        else:review_number.append(rnumber.text.strip())
        
        time.sleep(0.02)
        
get_hotel_info(hotel_urls)

# %%
#Create a DataFrame using the four lists
df_data = pd.DataFrame(
    {'Name': hotel_names,
     'URL': hotel_urls,
     'Class of Rating': rating_class,
     'Rating Score': rating_score,
     'Review Number': review_number
    })

df_data
# Out:
#     Class of Rating                                             Name  \
# 0         Excellent                                   Oakwood Boston
# 1         Very Good          14 Gloucester St #2B by Lyon Apartments
# 2         Very Good          14 Gloucester St #2A by Lyon Apartments
# 3           Awesome                             Seaport Boston Hotel
# 4         Very Good        Longfellow Place Apartment by Stay Alfred
# 5              Good        Clearway Street by Boston Furnished Rooms
# 6         Very Good                                 The Copley House
# 7       Exceptional              Two Bedroom Boston Luxury Apartment
# 8         Very Good                             Aloft Boston Seaport
# 9         Very Good              112 Myrtle St #7 by Lyon Apartments
# 10        Very Good          14 Gloucester St #4A by Lyon Apartments
# 11     Review score                                    Ramada Boston
# 12        Very Good                      Hilton Boston Logan Airport
# 13        Very Good                             Hyatt Regency Boston
# 14        Very Good                 Boston Harbor View Luxury Suites
# 15        Very Good              Hilton Boston Downtown/Faneuil Hall
# 16        Very Good               102 Chandler #8 By Lyon Apartments
# 17        Very Good               102 Chandler #9 By Lyon Apartments
# 18             Good               102 Chandler #4 By Lyon Apartments
# 19        Very Good               102 Chandler #5 By Lyon Apartments
# 20        Excellent               102 Chandler #6 By Lyon Apartments
# 21          Awesome                               Loews Boston Hotel
# 22        Very Good                                     YOTEL Boston
# 23             Good         One-Bedroom on Washington Street Apt 207
# 24        Very Good         One-Bedroom on Washington Street Apt 304
# 25        Very Good                                        Hotel 140
# 26             Good     Global Luxury Suites at The Theater District
# 27        Excellent       Washington Street Apartment by Stay Alfred
# 28          Awesome                              Four Seasons Boston
# 29        Excellent                  The Westin Copley Place, Boston
# ..              ...                                              ...
# 381       Excellent                     Studio on Arch Street Apt 5B
# 382         Awesome           Two-Bedroom on Western Avenue Apt N314
# 383       Excellent           One-Bedroom on Warrenton Street Apt 18
# 384       Excellent                                  Bird's Eye View
# 385       Very Good              Relax n "think" about next business
# 386       Excellent     Royal Street Studio Apartment by RoyalStreet
# 387    Review score             One-Bedroom on Boylston Street Apt 8
# 388       Very Good             One-Bedroom on Beacon Street Apt 714
# 389            Good                One-Bedroom on Arch Street Apt 4D
# 390    Review score         Three-Bedroom on Western Avenue Apt S501
# 391            None           Two-Bedroom on Western Avenue Apt N306
# 392     Exceptional                                     Little Pearl
# 393            Good                     Oakwood at Watermark Seaport
# 394       Very Good                      Bluebird Suites at West End
# 395    Review score                               The Ledder House 5
# 396     Exceptional                                 Brighton Retreat
# 397            Good                                     Zakim's View
# 398    Review score                           Oakwood at 234 Newbury
# 399            None        One-Bedroom on Chestnut Hill Avenue Apt 9
# 400       Excellent                           Guild Street Townhouse
# 401       Very Good                       Beautiful Bunker Hill 2 Bd
# 402            Good                 Renovated Apartment Near Airport
# 403            None                One-Bedroom on Arch Street Apt 1B
# 404            None                         Colbyco at Andrew Square
# 405            None  COZY&HOMEY 2BR APT! 1 FullBath & 1 free parking
# 406            None                          Copenger street 5BR/3BA
# 407            None                           301 on Washington Apts
# 408            None                           206 on Washington Apts
# 409            None                           201 on Washington Apts
# 410       Excellent                      North End Enchanted Cottage
#
#     Rating Score  Review Number  \
# 0            8.7     85 reviews
# 1            8.1  2,805 reviews
# 2             10     42 reviews
# 3            9.1  1,921 reviews
# 4            8.5    205 reviews
# 5            7.3    136 reviews
# 6            8.1  2,805 reviews
# 7            9.8     24 reviews
# 8            8.5    765 reviews
# 9            8.0     15 reviews
# 10           8.8     42 reviews
# 11           6.9  2,252 reviews
# 12           8.1  2,169 reviews
# 13           8.5  1,382 reviews
# 14           8.2    172 reviews
# 15           8.5    710 reviews
# 16           8.4    334 reviews
# 17           8.5  1,986 reviews
# 18           7.3    136 reviews
# 19           8.1  2,805 reviews
# 20           8.7  1,746 reviews
# 21           9.0  2,023 reviews
# 22           8.3    420 reviews
# 23           7.8     47 reviews
# 24           8.2    440 reviews
# 25           8.0  2,708 reviews
# 26           7.8     47 reviews
# 27           8.9    254 reviews
# 28           9.0    198 reviews
# 29           8.6  1,192 reviews
# ..           ...            ...
# 381          8.8     72 reviews
# 382           10    200 reviews
# 383          8.6  1,212 reviews
# 384          9.6  5,657 reviews
# 385          8.5    765 reviews
# 386          8.8     10 reviews
# 387          6.0      7 reviews
# 388          8.1     13 reviews
# 389          7.9     12 reviews
# 390          6.5      8 reviews
# 391         None           None
# 392          9.8      6 reviews
# 393          7.3    136 reviews
# 394          8.2    172 reviews
# 395          6.7     21 reviews
# 396          9.6      8 reviews
# 397          7.3    136 reviews
# 398          6.9    204 reviews
# 399         None           None
# 400          8.8      6 reviews
# 401           10    172 reviews
# 402          7.7    811 reviews
# 403         None           None
# 404         None           None
# 405         None           None
# 406         None           None
# 407         None           None
# 408         None           None
# 409         None           None
# 410          8.6  1,360 reviews
#
#                                                    URL
# 0    http://booking.com/hotel/us/oakwood-boston.htm...
# 1    http://booking.com/hotel/us/14-gloucester-st-2...
# 2    http://booking.com/hotel/us/14-gloucester-st-2...
# 3    http://booking.com/hotel/us/seaport.html#hotel...
# 4    http://booking.com/hotel/us/longfellow-by-stay...
# 5    http://booking.com/hotel/us/clearway-street-by...
# 6    http://booking.com/hotel/us/the-c-house-boston...
# 7    http://booking.com/hotel/us/two-bedroom-boston...
# 8    http://booking.com/hotel/us/aloft-boston-seapo...
# 9    http://booking.com/hotel/us/112-myrtle-st-7.ht...
# 10   http://booking.com/hotel/us/14-gloucester-st-4...
# 11   http://booking.com/hotel/us/r-boston-massachus...
# 12   http://booking.com/hotel/us/hilton-logan-airpo...
# 13   http://booking.com/hotel/us/hyatt-regency-bost...
# 14   http://booking.com/hotel/us/boston-harbor-view...
# 15   http://booking.com/hotel/us/hilton-boston-fin-...
# 16   http://booking.com/hotel/us/102-chandler-8-by-...
# 17   http://booking.com/hotel/us/102-chandler-9-by-...
# 18   http://booking.com/hotel/us/102-chandler-4-by-...
# 19   http://booking.com/hotel/us/102-chandler-5-by-...
# 20   http://booking.com/hotel/us/102-chandler-6-by-...
# 21   http://booking.com/hotel/us/loews-boston-hotel...
# 22   http://booking.com/hotel/us/yotel-boston.html#...
# 23   http://booking.com/hotel/us/one-bedroom-on-was...
# 24   http://booking.com/hotel/us/one-bedroom-on-was...
# 25      http://booking.com/hotel/us/140.html#hotelTmpl
# 26   http://booking.com/hotel/us/luxury-apartments-...
# 27   http://booking.com/hotel/us/660-washington-by-...
# 28   http://booking.com/hotel/us/four-seasons-bosto...
# 29   http://booking.com/hotel/us/westin-copley-plac...
# ..                                                 ...
# 381  http://booking.com/hotel/us/studio-on-arch-str...
# 382  http://booking.com/hotel/us/apartment-on-weste...
# 383  http://booking.com/hotel/us/one-bedroom-apartm...
# 384  http://booking.com/hotel/us/birds-eye-view-bos...
# 385  http://booking.com/hotel/us/relax-n-quot-think...
# 386  http://booking.com/hotel/us/royal-street-studi...
# 387  http://booking.com/hotel/us/one-bedroom-apartm...
# 388  http://booking.com/hotel/us/pristine-brookline...
# 389  http://booking.com/hotel/us/apartment-on-arch-...
# 390  http://booking.com/hotel/us/three-bedroom-apar...
# 391  http://booking.com/hotel/us/apartment-on-weste...
# 392  http://booking.com/hotel/us/little-pearl.html#...
# 393  http://booking.com/hotel/us/watermark-seaport....
# 394  http://booking.com/hotel/us/bluebird-suites-at...
# 395  http://booking.com/hotel/us/the-ledder-house-5...
# 396  http://booking.com/hotel/us/brighton-retreat-b...
# 397  http://booking.com/hotel/us/zakims-view.html#h...
# 398  http://booking.com/hotel/us/234-newbury.html#h...
# 399  http://booking.com/hotel/us/one-bedroom-on-che...
# 400  http://booking.com/hotel/us/guild-street-townh...
# 401  http://booking.com/hotel/us/beautiful-bunker-h...
# 402  http://booking.com/hotel/us/boston.html#hotelTmpl
# 403  http://booking.com/hotel/us/one-bedroom-apartm...
# 404  http://booking.com/hotel/us/colbyco-at-andrew-...
# 405  http://booking.com/hotel/us/cozy-amp-homey-2br...
# 406  http://booking.com/hotel/us/copenger-street-5b...
# 407  http://booking.com/hotel/us/301-on-washington-...
# 408  http://booking.com/hotel/us/206-on-washington-...
# 409  http://booking.com/hotel/us/201-on-washington-...
# 410  http://booking.com/hotel/us/north-end-enchante...
#
# [411 rows x 5 columns]

# %%
#Store hotel data in a csv file
df_data.to_csv('traveler_ratings.csv', encoding='utf-8')

# %% [markdown]
# Now let's scrape some reviews. For each review of each each hotel in Boston you are to scrape the following attributes:
# 1. Reviewer name
# 2. Reviewer ethnicity
# 3. Number of reviews
# 4. Number of helpful votes
# 5. Date
# 6. Rating
# 7. Negative Review
# 8. Positive Review
#
# Note that you will also need the hotel's name!! Also, some reviews may not have all attributes.
#
# ** Save the data in "review_ratings.csv" in the following format: hotel_name, reviewer_name, ethnicity, num_reviews, num_help_votes, date, rating, neg_review, pos_review **
#
# **(25 pts)**
#
# You can see an overview of the information as displayed:
# ![Information to be scraped](review_sample.png)

# %%
'''
Experiment on one page with reviews

'''

webUrl = "https://www.booking.com/hotel/us/loews-boston-hotel.html?aid=304142;label=gen173nr-1DCAEoggJCAlhYSDNiBW5vcmVmcgV1c19tYYgBAZgBMcIBA2FibsgBDdgBA-gBAfgBApICAXmoAgQ;sid=f7bbc22a8ecfb41b5a7bc29715b9f05e;dest_id=20061717;dest_type=city;dist=0;group_adults=2;hapos=1;hpos=1;room1=A%2CA;sb_price_type=total;srepoch=1509942585;srfid=4f87669b94b357cd9cfd533f9f2e96f49874620cX1;srpvid=80511f9cb82b0604;type=total;ucfs=1&#blockdisplay4"
response = requests.get(webUrl)
html = response.text.encode('utf-8')
page_soup = BeautifulSoup(html, "lxml")

country = page_soup.findAll('li', {'class':re.compile('review_item clearfix')})

name = country[1].find('h4').text.strip()
country_name = country[1].find('span', {'class' : 'reviewer_country'}).text.strip()
review_number = country[1].find('div', {'class' : 'review_item_user_review_count'})
helpful_review = country[1].find('div', {'class':'review_item_user_helpful_count'})
rating = country[1].find('span', {'class':'review-score-badge'})
date = country[1].find('p', {'class' : 'review_item_date'})
neg = country[1].find('p', {'class':'review_neg'})
positive = country[1].find('p', {'class':'review_pos'})

print(name)
if country_name is not None:print(country_name)
if review_number is not None:print(review_number)
if helpful_review is not None: print(helpful_review)
if rating is not None:print(rating)
if date is not None:print(date)
# if neg is not None:print(neg[0])
# if positive is not None:print(positive[0])
# Out:
# AsliDe
# Turkey
# <span class="review-score-badge">
# 9.2
# </span>
# <p class="review_item_date">
# November 6, 2017
# </p>

# %%
'''
Extract all reviews for one hotel

'''
def extract_hotel_info(hotel_name, hotel_url, info_list):
    response = requests.get(hotel_url)
    html = response.text.encode('utf-8')
    page_soup = BeautifulSoup(html, "lxml")
    
    if page_soup is None: return  #If cannot get webpage, skip

    review_page = page_soup.find('a', {'class':'show_all_reviews_btn'}) #Find review page's url
    if review_page is None: return  #If no reviews, skip
    
    base_page = "http://www.booking.com"
    review_page_url = base_page + review_page['href']
    
    
    #Get all reviews for this particula hotel if next page exists
    while(True):
        response = requests.get(review_page_url)
        html = response.text.encode('utf-8')
        page_soup = BeautifulSoup(html, 'lxml') #page_soup has html data for this page
        
        if page_soup is None: return  #If cannot get webpage, skip

        #Get all reviews on this page
        containers = page_soup.findAll('li', {'class':re.compile('review_item clearfix')})
        for item in containers:  #item has the data from one review
            tmp_list = []
            tmp_list.append(hotel_name)
            
            name = item.find('h4')
            if name is not None: tmp_list.append(name.text.strip())
            else: tmp_list.append(None)
                  
            country_name = item.find('span', {'class' : 'reviewer_country'})
            if country_name is not None: tmp_list.append(country_name.text.strip())
            else: tmp_list.append(None)
            
            review_number = item.find('div', {'class' : 'review_item_user_review_count'})
            if review_number is not None: tmp_list.append(review_number.text.strip())
            else: tmp_list.append(None)

            helpful_review = item.find('div', {'class':'review_item_user_helpful_count'})
            if helpful_review is not None: tmp_list.append(helpful_review.text.strip())
            else: tmp_list.append(None)
                
            rating = item.find('span', {'class':'review-score-badge'})
            if rating is not None: tmp_list.append(rating.text.strip())
            else: tmp_list.append(None)
                
            review_date = item.find('p', {'class' : 'review_item_date'})
            if review_date is not None: tmp_list.append(review_date.text.strip())
            else: tmp_list.append(None)
                
            neg = item.find('p', {'class':'review_neg'})
            if neg is not None:
                review_text = neg.find('span', {'itemprop': 'reviewBody'})
                if review_text is not None:
                    s = review_text.text.strip()
                    s = re.sub(r'[\n\r\t]*', '', s) #Get rit of special characters
                    tmp_list.append(s)  
                else: tmp_list.append(None)
            else: tmp_list.append(None)
            
            
            positive = item.find('p', {'class':'review_pos'})
            if positive is not None:
                review_text = positive.find('span', {'itemprop': 'reviewBody'})
                if review_text is not None:
                    s = review_text.text.strip()
                    s = re.sub(r'[\n\r\t]*', '', s) #Get rit of special characters
                    tmp_list.append(s)  
                else: tmp_list.append(None)
            else: tmp_list.append(None)
            
            info_list.append(tmp_list) #One entry added to the final result; For loop ends.
           
        
        
        #Try update url to the next page if exists
        next_url = page_soup.find('p', {'class':'page_link review_next_page'})
        if next_url is None: break  #Dealing with invalid page
        
        tag = next_url.find('a', {'href': True})
        if tag is None: break  #Dealing with invalid page

        else: 
            review_page_url = base_page + tag['href'].rstrip()
            time.sleep(0.02)

# %%
info_list = [] #Store all data here

#Given hotel names and their corresponding urls, extract all reviews for all hotel and store them in info_list

for i in range(len(hotel_urls)):
    extract_hotel_info(hotel_names[i], hotel_urls[i], info_list)

# %%
len(info_list)
# Out:
# 56606

# %% [markdown]
# # excluded
# url_1 = "https://www.booking.com/reviews/us/hotel/loews-boston-hotel.html?aid=304142;label=gen173nr-1DCAEoggJCAlhYSDNiBW5vcmVmcgV1c19tYYgBAZgBMcIBA2FibsgBDdgBA-gBAfgBApICAXmoAgQ;sid=f7bbc22a8ecfb41b5a7bc29715b9f05e"
# url_2 = 'https://www.booking.com/reviews/us/hotel/oakwood-boston.html?aid=304142;label=gen173nr-1DCAEoggJCAlhYSDNiBW5vcmVmcgV1c19tYYgBAZgBMcIBA2FibsgBDdgBA-gBAfgBApICAXmoAgQ;sid=f7bbc22a8ecfb41b5a7bc29715b9f05e'
# response_ = requests.get(url_1)
# html_ = response_.text.encode('utf-8')
# page_soup_ = BeautifulSoup(html_, "lxml")
#
# next_url = page_soup_.find('p', {'class':'page_link review_next_page'}).find('a', {'href': True})['href'].rstrip()
# next_url

# %%
df_reviews = pd.DataFrame(info_list)
df_reviews
# Out:
#                                           0              1  \
# 0                            Oakwood Boston       Caroline
# 1                            Oakwood Boston      Anonymous
# 2                            Oakwood Boston             Dr
# 3                            Oakwood Boston      Anonymous
# 4                            Oakwood Boston          Robin
# 5                            Oakwood Boston      Overseeas
# 6                            Oakwood Boston             Aj
# 7                            Oakwood Boston          Susan
# 8                            Oakwood Boston          Susan
# 9                            Oakwood Boston      Anonymous
# 10                           Oakwood Boston          Carol
# 11                           Oakwood Boston        Alfonso
# 12                           Oakwood Boston           Aura
# 13                           Oakwood Boston            Ana
# 14                           Oakwood Boston         Tarana
# 15                           Oakwood Boston       Danielle
# 16                           Oakwood Boston         Family
# 17                           Oakwood Boston  Trevor Travel
# 18                           Oakwood Boston  DR.ABHAY SHAH
# 19                           Oakwood Boston           Amer
# 20                           Oakwood Boston          James
# 21                           Oakwood Boston        Michael
# 22                           Oakwood Boston    Christopher
# 23                           Oakwood Boston              D
# 24                           Oakwood Boston        Barbara
# 25                           Oakwood Boston      Gena12712
# 26                           Oakwood Boston      Anonymous
# 27                           Oakwood Boston          Susan
# 28                           Oakwood Boston        Leonard
# 29                           Oakwood Boston        Hakeema
# ...                                     ...            ...
# 56576                      Chandler Studios           John
# 56577                      Chandler Studios        Deborah
# 56578                      Chandler Studios         Roland
# 56579                      Chandler Studios      Anonymous
# 56580                      Chandler Studios            Pia
# 56581  One-Bedroom on Boylston Street Apt 8         Khaled
# 56582  One-Bedroom on Boylston Street Apt 8       Maryanne
# 56583  One-Bedroom on Boylston Street Apt 8           Luke
# 56584  One-Bedroom on Beacon Street Apt 714        Bettina
# 56585  One-Bedroom on Beacon Street Apt 714         Jacqui
# 56586  One-Bedroom on Beacon Street Apt 714        Darnell
# 56587  One-Bedroom on Beacon Street Apt 714          Sarah
# 56588     One-Bedroom on Arch Street Apt 4D        Barbara
# 56589     One-Bedroom on Arch Street Apt 4D           Axel
# 56590     One-Bedroom on Arch Street Apt 4D  Lenayinanwang
# 56591     One-Bedroom on Arch Street Apt 4D          Fiona
# 56592                          Little Pearl          Marty
# 56593                          Little Pearl           Mary
# 56594                          Little Pearl      Anonymous
# 56595                          Little Pearl           Rich
# 56596                          Little Pearl         Nicole
# 56597                    The Ledder House 5         Wouter
# 56598                    The Ledder House 5      Anonymous
# 56599                    The Ledder House 5      Elizabeth
# 56600                    The Ledder House 5         Lorena
# 56601                    The Ledder House 5          Nawab
# 56602                    The Ledder House 5         Alexey
# 56603                Guild Street Townhouse        Kathryn
# 56604                Guild Street Townhouse      Anonymous
# 56605                Guild Street Townhouse         Joseph
#
#                               2           3     4    5                   6  \
# 0                        France   5 Reviews  None  8.3    November 3, 2017
# 1                     Australia    1 review  None  9.6    October 28, 2017
# 2                         Qatar   4 Reviews  None   10    October 26, 2017
# 3                   Switzerland   8 Reviews  None  8.8    October 17, 2017
# 4      United States of America   4 Reviews  None  6.3  September 15, 2017
# 5                  Saudi Arabia   2 Reviews  None  7.5       July 27, 2017
# 6                         Egypt   3 Reviews  None  4.6        July 2, 2017
# 7                     Australia  14 Reviews  None   10        May 28, 2017
# 8      United States of America    1 review  None  9.6        May 25, 2017
# 9                        Canada    1 review  None  9.2        May 24, 2017
# 10                       Canada   2 Reviews  None  7.5        May 24, 2017
# 11                   Costa Rica   3 Reviews  None  6.7      April 21, 2017
# 12                      Romania   9 Reviews  None  8.3      April 12, 2017
# 13                       Panama   2 Reviews  None  8.8       March 1, 2017
# 14                   Azerbaijan   6 Reviews  None  8.8   February 26, 2017
# 15     United States of America   5 Reviews  None   10   December 10, 2016
# 16     United States of America    1 review  None  9.6    December 9, 2016
# 17                      Bermuda    1 review  None  8.3   November 21, 2016
# 18                        India   2 Reviews  None  8.8  September 23, 2016
# 19     United States of America   4 Reviews  None   10       June 14, 2016
# 20                 South Africa   7 Reviews  None  5.0   November 13, 2015
# 21                      Ireland   5 Reviews  None   10    November 3, 2017
# 22                    Australia   5 Reviews  None  7.5    October 30, 2017
# 23                 Saudi Arabia   2 Reviews  None  9.2    October 26, 2017
# 24     United States of America    1 review  None  8.3    October 26, 2017
# 25     United States of America   4 Reviews  None  7.9    October 25, 2017
# 26                      Ireland    1 review  None  9.6    October 24, 2017
# 27               United Kingdom   3 Reviews  None  8.8    October 15, 2017
# 28     United States of America    1 review  None  7.9     October 8, 2017
# 29                      Bahrain  11 Reviews  None  9.6     October 1, 2017
# ...                         ...         ...   ...  ...                 ...
# 56576  United States of America    1 review  None  9.6       July 15, 2013
# 56577                    Canada    1 review  None  9.2       June 16, 2013
# 56578  United States of America    1 review  None  8.8       June 14, 2013
# 56579               Netherlands    1 review  None  8.5        May 22, 2013
# 56580  United States of America    1 review  None  9.6      April 20, 2013
# 56581      United Arab Emirates   3 Reviews  None  6.3        July 1, 2017
# 56582                 Australia   6 Reviews  None  7.5      April 25, 2017
# 56583            United Kingdom    1 review  None  8.3      March 25, 2017
# 56584                    France   5 Reviews  None  8.3   November 12, 2016
# 56585            United Kingdom   5 Reviews  None  9.2     August 14, 2016
# 56586  United States of America    1 review  None   10  September 28, 2017
# 56587  United States of America    1 review  None  8.8      April 21, 2017
# 56588  United States of America    1 review  None  8.8      March 13, 2017
# 56589                  Colombia  10 Reviews  None  7.1      August 7, 2017
# 56590  United States of America   6 Reviews  None  9.6        May 24, 2017
# 56591      United Arab Emirates  33 Reviews  None  8.5    October 16, 2016
# 56592                 Australia    1 review  None   10   September 6, 2017
# 56593  United States of America   4 Reviews  None  9.6       June 21, 2017
# 56594                     India    1 review  None  9.2    October 23, 2017
# 56595  United States of America   9 Reviews  None   10       July 10, 2017
# 56596  United States of America    1 review  None   10        June 5, 2017
# 56597                   Belgium  44 Reviews  None  7.9    November 2, 2017
# 56598  United States of America    1 review  None  7.9    October 30, 2017
# 56599            United Kingdom  26 Reviews  None  8.3    October 16, 2017
# 56600                    Canada    1 review  None  4.2     August 25, 2017
# 56601  United States of America    1 review  None  2.9    October 19, 2017
# 56602  United States of America  29 Reviews  None  6.7    October 16, 2017
# 56603  United States of America    1 review  None  9.6  September 30, 2017
# 56604  United States of America    1 review  None  4.6     August 10, 2017
# 56605  United States of America    1 review  None   10       June 30, 2017
#
#                                                        7  \
# 0      Cleanliness in the common area is not very goo...
# 1      No concerns. The gym room was small but manage...
# 2                                                   None
# 3                                                   None
# 4      The bed is miserably uncomfortable.  The showe...
# 5                            Carpet needs to be cleaner.
# 6      The house keeping is sooo expensive and they d...
# 7      There was no kettle and the fridge was really ...
# 8      Booking this property is confusing.  You recei...
# 9      It seems oakwood has some learning to do relat...
# 10     They do not offer parking, which makes things ...
# 11     Appliances and houseware in the bathroom and k...
# 12     Since it's not a hotel, but an apartment build...
# 13     The halls of the Aparthotel are not very elega...
# 14     Furniture is a bit outdated, stovetop should b...
# 15                              Can't think of anything.
# 16     They cleaned the rug in the hall when we were ...
# 17     Staff could have been a a little more helpful....
# 18     They messed up my booking dates both check in ...
# 19                                                  None
# 20     The location is very very noisy. Police, Ambul...
# 21                                 Early morning traffic
# 22     Initially overcharged for room which took far ...
# 23                                                  None
# 24     Bed was not very comfortable, nor was the livi...
# 25                                      Appliances & bed
# 26                                                  None
# 27                                  Tea, coffee provided
# 28     Strange vomit smell in the lobby and elevators...
# 29                                   Everything was good
# ...                                                  ...
# 56576                                         no comment
# 56577       Just one chair in room.  Not enough seating.
# 56578  Check-in procedure a bit cumbersome because in...
# 56579                         Internet should be faster.
# 56580  there was only one chair for the table to have...
# 56581  They forgot to leave sheets and linens for the...
# 56582  Booked for 3 people but there wasn't any linen...
# 56583                                               None
# 56584  The price announced on booking was 250 euros l...
# 56585  Hooks on bathroom door!More info re the local ...
# 56586  Lockbox jammed for abt 15 m. Fixed with concie...
# 56587  The instructions to get in were very vague and...
# 56588  We had a run-in with a homeless man who set up...
# 56589  Lack of night tables at the bedroom.Lack of a ...
# 56590    4pm check-in time with no free luggage storage.
# 56591     Very expensive for a small one bed appartment.
# 56592                                               None
# 56593                              No complaints at all.
# 56594                        No toiletries were provided
# 56595                  Wish we could have stayed longer!
# 56596                  Wish we could have stayed longer!
# 56597                                               None
# 56598  As always in this style accommodation, it can ...
# 56599  Traffic noise as on main road very close to Po...
# 56600  Bed mattress way too cheap, toilet paper way t...
# 56601       It's just a house. No room service. No name.
# 56602  There is actually no parking in the hotel. I h...
# 56603  Construction was going on across the street in...
# 56604  Not the safest location. The neighbors were ha...
# 56605  Nope everything was great (there was construct...
#
#                                                        8
# 0      Very nice staff, although not very present.The...
# 1      Convenient location. Helpful concierge after h...
# 2      Good locationFamily friendly2 bedrooms and 2 b...
# 3      FABULOUS location (historic sites, aquarium, Q...
# 4      Property is in a great location. Central to ev...
# 5      Two bedrooms and 2 bathrooms. Good space for s...
# 6                                                   None
# 7      Really good location in a beautiful building. ...
# 8      The location is perfect.  We traveled with our...
# 9      Excellent location and very suitable for our n...
# 10     It is located near the subway and very easy to...
# 11     The bed was comfortable.The location is very g...
# 12            Great localtion and great value for money!
# 13     The OAKWOOD apartments are excellent. They hav...
# 14     Great location in downtown, clear check in and...
# 15     I was in Boston visiting with my daughter who ...
# 16     The beds were very comfortable! It was great t...
# 17     The room had full amenities including all nece...
# 18                                              Location
# 19     Position of the hotel is perfect for tourists ...
# 20                                     Clean, functional
# 21                                        Great Locality
# 22            LocationWashing machine/dryerWell equipped
# 23     Good utilization of space, nice apartment, cle...
# 24                                                  None
# 25                                        Location, size
# 26                                              Location
# 27     Bed very comfy.  Spacious apartment with every...
# 28                         Location and clean amenities.
# 29     Spacious , clean and well equipped . Central l...
# ...                                                  ...
# 56576  A well maintained studio apartment being utili...
# 56577       The contemporary decor.  Excellent location.
# 56578                     Staff very friendly, nice room
# 56579  I liked the bed and a great photo all over the...
# 56580                                 Modern, no clutter
# 56581  the location is beyond GREAT! and the manageme...
# 56582  Convenient location, warm apartment on a cold ...
# 56583                                      Very central.
# 56584                              The calm and location
# 56585  Comfortable bedGood showerEffective tvPlenty o...
# 56586                       Easy access. Great location.
# 56587  I liked that there was everything we needed to...
# 56588                                               None
# 56589   Convenience of location in downtown. Decoration.
# 56590  Perfect location!!! Clean room. Self check-in/...
# 56591      Great location. Very central and close to a T
# 56592  We had a fabulous time on Little Pearl - it wa...
# 56593  In a lovely, quiet waterfront neighborhood. Se...
# 56594  Experience of staying at the marina close to t...
# 56595  An awesome time away. Everything was amazing. ...
# 56596  Comfy and cozy, perfect for a couples weekend ...
# 56597  The hosts were great in welcoming us, showing ...
# 56598  Host was helpful and polite. It’s a 1 of 5 roo...
# 56599  Friendly and helpful host.Clean room and commu...
# 56600                                               None
# 56601                                     Nothing at all
# 56602                                               None
# 56603  The hosts were very nice and welcoming and mad...
# 56604                         There wasn't much to like.
# 56605  We loved that out kids each had their own beds...
#
# [56606 rows x 9 columns]

# %%
df_reviews.to_csv('review_ratings.csv', encoding='utf-8')
